# %%
# Use Matplotlib for rendering because it can draw inline (replace with WebRTC)
# %matplotlib inline

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt

# %%
img = cv2.imread('../data/owl.jpg', cv2.IMREAD_COLOR)
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
# Use Matplotlib to render the image inline
plt.imshow(img_rgb)
plt.show()
